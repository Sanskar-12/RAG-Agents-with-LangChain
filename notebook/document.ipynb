# %% [markdown]
# ## Data Ingestion

# %%
### Document Structure (parsing)

from langchain_core.documents import Document

# %%
### converting the pdf,excel,csv... into document structure so that it could be easy to parse the data, and metadata is used to apply further filtering of the document


doc=Document(
    page_content="This is the main text content and i am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Sanskar Vishwakarma",
        "date_created":"2026-04-23"
    }
)

# %%
print(doc)
# Out:
# page_content='This is the main text content and i am using to create RAG' metadata={'source': 'example.txt', 'pages': 1, 'author': 'Sanskar Vishwakarma', 'date_created': '2026-04-23'}

# %%
### Create  a simple txt file

import os

os.makedirs("./data/text_files",exist_ok=True)

# %%
# Meaningful text content
text = """Agentic AI systems are designed to perform tasks autonomously by combining reasoning, memory, and tool usage.

In modern applications, agents can translate natural language into structured queries such as SQL, validate them, and retrieve real-time data from databases.

This approach enables dynamic data retrieval without relying on traditional embedding-based retrieval methods, making it efficient for structured data systems.

Such systems are widely used in applications like chatbots, analytics platforms, and intelligent assistants."""

# File path
file_path = "./data/text_files/sample.txt"

# Write to file
with open(file_path, "w") as f:
    f.write(text)

print("File created at:", file_path)
# Out:
# File created at: ./data/text_files/sample.txt

# %%
### Text Loader to read the text and convert into Document

from langchain_community.document_loaders import TextLoader

loader=TextLoader("./data/text_files/sample.txt",encoding="utf-8")

document=loader.load()

print(document)
# Out:
# [Document(metadata={'source': './data/text_files/sample.txt'}, page_content='Agentic AI systems are designed to perform tasks autonomously by combining reasoning, memory, and tool usage.\n\nIn modern applications, agents can translate natural language into structured queries such as SQL, validate them, and retrieve real-time data from databases.\n\nThis approach enables dynamic data retrieval without relying on traditional embedding-based retrieval methods, making it efficient for structured data systems.\n\nSuch systems are widely used in applications like chatbots, analytics platforms, and intelligent assistants.')]

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader=DirectoryLoader(
    "./data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=True
)

documents=dir_loader.load()

print(documents)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1144.11it/s]
# [Document(metadata={'source': 'data/text_files/sample.txt'}, page_content='Agentic AI systems are designed to perform tasks autonomously by combining reasoning, memory, and tool usage.\n\nIn modern applications, agents can translate natural language into structured queries such as SQL, validate them, and retrieve real-time data from databases.\n\nThis approach enables dynamic data retrieval without relying on traditional embedding-based retrieval methods, making it efficient for structured data systems.\n\nSuch systems are widely used in applications like chatbots, analytics platforms, and intelligent assistants.')]

# %%
from langchain_community.document_loaders import PyMuPDFLoader

dir_loader=DirectoryLoader(
    "./data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=True
)

pdf_documents=dir_loader.load()

print(pdf_documents)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 88.67it/s]
# ...
